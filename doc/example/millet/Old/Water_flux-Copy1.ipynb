# %% [markdown]
# # Millet Model

# %% [markdown]
# Architectural parameters
# ------------------------
#   - $n$ : number of nodes in primary root
#   - $\delta$: reference distance between successive branching axis
#   - $\beta$ : branching variability or Number of nodes between successive ramification
#   - $order_{max}$ : maximum order of ramification
#   - $\lambda$ : number of nodes in nude tip zone
#   - $radius$ : external radius of the main axis of the roots
#   - $crown\_length$ : length of crown roots
#   - $crown\_nb$ : number of crown roots

# %%
#This is the pythonPATH of the classical Python
#l=['', 'C:\\Python27\\lib\\site-packages\\pyzmq-14.1.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\mingw-5.1.4_4c-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\mingw_rt-5.1.4_4c-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\qt4-4.8.5-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\pylsm-0.1_r34-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\python_dateutil-2.2-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.core-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.deploy-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.deploygui-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.grapheditor-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.image-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.misc-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.numpy-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.pkgbuilder-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.pylab-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.scheduler-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.sconsx-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.stdlib-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.visualea-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.vpltk-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\ann-1.1.2-win32.egg', 'C:\\Python27\\lib\\site-packages\\bisonflex-2.4.1_2.5.35-win32.egg', 'C:\\Python27\\lib\\site-packages\\boost-1.48.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\cmake-2.8.11.2-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\qt4_dev-4.8.5-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\qhull-2003.1-win32.egg', 'C:\\Python27\\lib\\site-packages\\rpy2-2.3.revf075a4291e9c-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\scons-2.3.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\pyqglviewer-2.3.17-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\openalea.container-2.3.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.mtg-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.pglviewer-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\openalea.svgdraw-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.aml-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.aml2py-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.amlobj-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.fractalysis-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.lpy-2.4.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.mechanics-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.mtg-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.phyllotaxis_analysis-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.physics-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.plantgl-2.19.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.self_similarity-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.sequence_analysis-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.stat_tool-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.celltissue-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.genepattern-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.growth-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.tissueedit-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.tissueshape-0.9.1-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.tissueview-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tissue.vmanalysis-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tool-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tree-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tree_matching-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tree_matching2-1.0.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tree_statistic-1.2.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\vplants.weberpenn-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\alinea.adel-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\alinea.astk-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\alinea.caribu-6.1.0-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\alinea.topvine-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\vplants.pglviewer-0.1.0.egg', 'C:\\Python27\\lib\\site-packages\\vplants.svgdraw-0.1.0.egg', 'C:\\Python27\\lib\\site-packages\\vplants.tuto-0.1.0.egg', 'C:\\Python27\\lib\\site-packages\\gnuplot-4.2.2_1-win32.egg', 'C:\\Python27\\lib\\site-packages\\eigen-3.0.7-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\cgal-4.2-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\ipython-3.0.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\mock-1.0.1-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\nose-1.3.4-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\mistune-0.5-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\requests-2.5.3-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\sphinx-1.3b3-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\jinja2-2.7.3-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\jsonschema-2.4.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\tornado-4.1-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\numpydoc-0.5-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\colorama-0.3.3-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\sphinx_rtd_theme-0.1.6-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\alabaster-0.7.1-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\babel-1.3-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\snowballstemmer-1.2.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\docutils-0.12-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\invoke-0.9.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\pygments-2.0.2-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\markupsafe-0.23-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\backports.ssl_match_hostname-3.4.0.2-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\certifi-14.05.14-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\pytz-2014.10-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\pyparsing-2.0.3-py2.7-win32.egg', 'C:\\Python27\\lib\\site-packages\\six-1.9.0-py2.7.egg', 'c:\\users\\ndour\\desktop\\mon dossier\\my_ph.d\\modeling_and_programming\\codes-mtg\\svn\\millet\\src', 'C:\\Python27\\lib\\site-packages\\vplants.hydroroot-1.0.0-py2.7.egg', 'C:\\Python27\\lib\\site-packages\\statsmodels-0.6.1-py2.7-win32.egg', 'C:\\Python27\\ C:\\Python27\\Lib\\site-packages\\rpy2', 'C:\\Program Files\\R\\R-3.2.3\\bin\\i386', 'C:\\Python27\\Lib\\site-packages\\shared_libs', 'c:\\python27\\lib\\site-packages\\scons-2.3.0-py2.7-win32.egg\\EGG-INFO\\scripts', 'c:\\python27\\lib\\site-packages\\ann-1.1.2-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\vplants.plantgl-2.19.0-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\qt4-4.8.5-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\vplants.aml-1.2.0-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\gnuplot-4.2.2_1-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\mingw-5.1.4_4c-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\qt4_dev-4.8.5-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\bisonflex-2.4.1_2.5.35-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\cgal-4.2-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\cmake-2.8.11.2-py2.7-win32.egg\\bin', 'c:\\python27\\lib\\site-packages\\alinea.caribu-6.1.0-py2.7-win32.egg\\bin', 'C:\\Python27\\Lib\\site-packages\\rpy2\\robjects', 'C:\\windows\\system32\\python27.zip', 'C:\\Python27\\DLLs', 'C:\\Python27\\lib', 'C:\\Python27\\lib\\plat-win', 'C:\\Python27\\lib\\lib-tk', 'C:\\Python27\\Lib\\site-packages\\pythonwin', 'C:\\Python27', 'C:\\Python27\\lib\\site-packages', 'C:\\Python27\\lib\\site-packages\\win32', 'C:\\Python27\\lib\\site-packages\\win32\\lib']

#Avoid import erros in IPython when path of IPython is different to that of python
#import sys
#for p in l:
    #if p not in sys.path:
        #sys.path.append(p)

# %%
#import and load pylab package
# %pylab inline
# %gui qt5
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# QApplication: invalid style override 'kvantum' passed, ignoring it.
# 	Available styles: Windows, Fusion

# %%
#Seminal
primary_length = 0.7
segment_length = 1.e-4
n = int(primary_length/segment_length)
nude_tip_length = (primary_length*0.15) / 0.75 # for a root 75cm-root we computed a 15cm nude tip length, so for a given root length we infer the corresponding length of apical zone
lamda = int(nude_tip_length/segment_length)
delta = 2.e-3 #branching rate
beta = 0.25
branching_delay = int(delta / segment_length)

#Crown root
crown_length = 0.12
m = int(crown_length/segment_length)
crown_nb = 2

# %% [markdown]
# Define a length law of LRs using equal amplitudes method from measured data
# -----------------------------------------------------------------------------------

# %%
import numpy as np
from openalea.hydroroot.millet import architecture, turtle, water, display_millet,law, age #, vptlkdisplay
from openalea.hydroroot import length, conductance, radius,flux,display as hdisplay
from openalea.plantgl.all import Viewer
# reload(law)
# reload(display_millet)
# reload(turtle)
# reload(water)
# reload(radius)
# reload(conductance)
# reload(flux)
# reload(architecture)

# %%
filename = 'lr_length_law_data.csv'
# xy = readCSVFile(filename)
# xy = np.genfromtxt(filename,delimiter=';')
import pandas as pd
xy = pd.read_csv(filename,sep=';')

# %%
xy
# Out:
#       position  LR_length
# 0    69.244796   0.395258
# 1    69.142877   0.670096
# 2    67.852152   1.050428
# 3    67.852152   1.638570
# 4    67.516075   1.824040
# ..         ...        ...
# 289  16.977880   0.071324
# 290  16.562852   0.084749
# 291  16.309130   0.076749
# 292  16.160565   0.064958
# 293  15.151452   0.052236
#
# [294 rows x 2 columns]

# %%
# from openalea.hydroroot.read_file import readCSVFile

# filename = 'lr_length_law_data.csv'
# # xy = readCSVFile(filename)
# xy = np.genfromtxt(filename,delimiter=';')

LR_length_law = law.expovariate_law(xy, size=5e-2, segment_length =1e-4, plot=True)

# %% [markdown]
# Compute architecture from architectural parameters $\&$ laws
# ------------------------------------------------------------------

# %%
#g = architecture.millet_mtg(LR_length_law = LR_length_law,nb_vertices=1500)
g = architecture.millet_mtg(nb_vertices = n,
                           nude_tip_length = lamda,
                           branching_delay = branching_delay,
                           crown_length = m,
                           nb_crown = crown_nb,
                           LR_length_law = LR_length_law
                           )

# %%
print(n, m)
print(len(g))
# Out:
# 6999 1200
# 32632

# %%
import numpy as np

pos = g.property('position_index')
branching_points= [21, 47, 68, 83, 106, 126, 152, 167, 189, 212, 233, 255, 275, 294, 317, 336, 360, 384, 400, 425, 447, 465, 482, 506, 525, 546, 572, 594, 611, 629, 650, 678, 699, 716, 739, 756, 782, 804, 818, 840, 867, 881, 908, 927, 945, 968, 992, 1011, 1031, 1055, 1076, 1099, 1113, 1136, 1155, 1177, 1196]
#ps =[LR_length_law(pos[i]) for i in branching_points]
m = min(branching_points)

M = max(branching_points)

k = pos.keys()

#print min(k),max(k)
#print LR_length_law(300)

print(LR_length_law(pos[m]),LR_length_law(pos[M]))
# Out:
# 52.227268295942395 54.17116108826959

# %%
g= radius.compute_length(g)
g = radius.compute_relative_position(g)

# %%
#length of seminal root
T = g.Trunk(g.root,g.max_scale())
print(len(T))
# Out:
# 7001

# %%
position = g.property('position')
val = position.values()
lst = [v for v in g.vertices() if g.node(v).position==None]
position[lst[0]]=len(g.Trunk(g.root,g.max_scale()))-1
#post_lst = [v for v in g.vertices() if g.node(v).position==None]

# %%
print(position[0])
# Out:
# 7000

# %% [markdown]
# Compute age of each vertex on the MTG
# -----------------------------------------

# %% [markdown]
# * ### Define seminal root growth law

# %%
def read_csv_data(file_name):
    xy = np.genfromtxt(file_name,float, delimiter=';',missing_values='na',filling_values=np.nan, names= True)
    return xy

# %%
sr_growth_data = 'seminal_growth_109.csv'
pq = pd.read_csv(sr_growth_data, sep=';')

# %%
pq
# Out:
#    13  5.44337383125
# 0  14      10.949335
# 1  15      17.869069
# 2  16      26.980238
# 3  17      35.609784
# 4  18      44.133955
# 5  19      51.971132
# 6  20      59.408799
# 7  21      66.298886

# %%
f = law.age_law(pq, segment_length = 1e-4,scale_x= 1, scale_y = 1.e-2, plot= True)

# %%
g = age.compute_age_with_constant_growth_speed(g)

# %%
ages = g.property('age')
ramifs = [vid for vid in g.vertices(g.max_scale()) if g.edge_type(vid)=='+']
#lrs = [list(algo.local_axis(g,v)) for v in ramifs]
#val = [[age[i] for i in vd] for vd in lrs]
#l= [ [min(j),max(j)] for j in val]

# %%
#l= [v for k,v in ages.iteritems() if g.label(k)=='Seminal' and g.order(k)==1]
#print l

# %%
#cr = [v for v in g.vertices() if g.label(v)=='Crown']
ramifs = [vid for vid in g.vertices(g.max_scale()) if g.edge_type(vid)=='+']
ls= [v for v in ramifs if g.label(v)=='Crown' ]
print(ls)
# Out:
# [30232, 31432]

# %% [markdown]
# Compute evolution laws of different root types diameter
# --------------------------------------------------------------

# %% [markdown]
# * ###   Define evolution laws of radius of different root types

# %%
def func(k, a, b):
    return a * np.log(k) + b

# %%
#Estimate diameter law of seminal root
sr_data = 'SR_diameters.csv'
xy = pd.read_csv(sr_data, sep=';')

# %%
sr_diameter_law = law.diameter_law(xy,function=func, segment_length = 1e-4, plot= True)

# %%
#Estimate diameter law of crown root
cr_data = 'CR_diameters.csv'
cr = pd.read_csv(cr_data, sep=';')
cr_diameter_law = law.diameter_law(cr,function=func, segment_length = 1e-4, plot= True)

# %%
#Estimate diameter law of lateral root
lr_data = 'LR_diameters.csv'
ij = pd.read_csv(lr_data, sep=';')
lr_diameter_law = law.diameter_law(ij,function=func, segment_length = 1e-4, plot= True)

# %% [markdown]
# * ### Compute radius for different root types

# %%
g= radius.compute_length(g)
g = law.compute_radius_from_laws(g,seminal_RootDiameter_law = sr_diameter_law,
                                    crown_RootDiameter_law = cr_diameter_law,
                                    lr_RootDiameter_law = lr_diameter_law)

# %%
r = g.property('radius')
val = r.values()
taille = len(g)
l=[v for v in g.vertices() if g.node(v).radius==None]
print(min(val),max(val))
print(l)
# Out:
# dict_values([0.00027, 0.00027, np.float64(0.00058207310097407), np.float64(0.0005820629363737653), np.float64(0.0005820527703204406), np.float64(0.0005820426028136807), np.float64(0.0005820324338530697), np.float64(0.000582022263438192), np.float64(0.0005820120915686315), np.float64(0.0005820019182439718), np.float64(0.0005819917434637971), np.float64(0.0005819815672276901), np.float64(0.0005819713895352346), np.float64(0.0005819612103860136), np.float64(0.0005819510297796099), np.float64(0.0005819408477156065), np.float64(0.0005819306641935855), np.float64(0.0005819204792131298), np.float64(0.0005819102927738212), np.float64(0.0005819001048752417), np.float64(0.0005818899155169736), np.float64(0.0005818797246985982), np.float64(0.000581869532419697), np.float64(0.0005818593386798513), np.float64(0.0005818491434786423), np.float64(0.000581838946815651), np.float64(0.000581828748690458), np.float64(0.0005818185491026441), np.float64(0.0005818083480517894), np.float64(0.000581798145537
# ...

# %%
g, surface = radius.compute_surface(g)
g, volume = radius.compute_volume(g)

print('Surface : ', surface)
print('Volume : ', volume)
# Out:
# Surface :  0.006937777554457133
# Volume :  1.3135293910635558e-06

# %% [markdown]
# Visualize architectural model as a Multiscale Tree Graph (MTG)
# ----------------------------------------------------------------------

# %%
display_millet.plot_mtg(g,save_image = True,static = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 display_millet.plot_mtg(g,save_image = True,static = True)
#
# File ~/Documents/Dev/hydroroot/src/openalea/hydroroot/millet/display_millet.py:51, in plot_mtg(g, static, save_image, dir)
#      49 l=map(int,l)
#      50 if static == True:
# ---> 51     g, scene = turtle.mtg_turtle_time(g,age_max)
#      52     Viewer.display(scene)
#      53 else:
#
# File ~/Documents/Dev/hydroroot/src/openalea/hydroroot/millet/turtle.py:145, in mtg_turtle_time(g, time, update_visitor, time_property)
#     142     return scene, g
#     144 for plant_id in g.component_roots_at_scale_iter(g.root, scale=max_scale):
# --> 145     scene, g = traverse_with_turtle_time(g, plant_id, time)
#     146 return g, scene
#
# ...

# %%
coord = g.property('xyz')
print type(coord[2])
# Out:
# <class 'openalea.plantgl.math._pglmath.Vector3'>

# %% [markdown]
# * ### Display MTG inside notebook

# %%
#Create scene
#age = g.property('age')
#t= max(age.values())
#g, scene = turtle.mtg_turtle_time(g,t)

#Display
#from IPython.display import display
#m = vptlkdisplay.PlantGL(scene)
#display(m)

# %% [markdown]
# Use HydroRoot model to compute Water flux
# ==========================================

# %% [markdown]
# * ### Define hydraulic parameters

# %%
length_data = [0., 0.03, 0.05, 0.16], [0., 0., 0.01, 0.13]
radial_conductivity_data = (
    [0., 0.015, 0.03, 0.045, 0.06, 0.075, 0.09, 0.105, 0.135, 0.15, 0.16], 
    [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300])


segment_length = 1e-4
ref_radius = 1e-4 # in m
order_decrease_factor = 0.7

# parameters
k0 = 300
Jv = 0.1
psi_e = 0.4
psi_base = 0.1

# %% [markdown]
# * ### Computation of Flux in millet root system

# %%
#Computation of g, surface, volume, Keq, Jv_global 

g, surface, volume, Keq, Jv_global = water.hydrolic(
    g,
    segment_length=segment_length,
    ref_radius = ref_radius,
    order_decrease_factor = order_decrease_factor,
    k0 = k0,
    Jv = Jv,
    psi_e = psi_e,
    psi_base = psi_base,
    length_data=length_data,
    axial_conductivity_data=None,
    radial_conductivity_data=radial_conductivity_data
    )

# %%
###### Test: plot properties

j = g.property('j')
K= g.property('K')

#scatter(j.values(),K.values())

print g.property_names()
# Out:
# ['J_out', 'diam', 'k0', 'geometry', 'k', 'age', 'j', 'label', 'psi_in', 'length', 'edge_type', 'radius', 'Keq', 'K', 'position', 'psi_out', 'relative_position', 'xyz', 'order', 'position_index']

# %%
print min(j.values()),max(j.values())
# Out:
# 0.000678213426906 0.00249436632841

# %% [markdown]
# Visualization of water fluxes in millet root system
# ==========================================

# %%
 display_millet.plot_property(g,static=False,save_image=True, prop_cmap='j', lognorm = True)
# Out:
# openalea.plantgl:86: Warning: <Oriented> Field 'Primary' has a bad value : Must be normalized.
# openalea.plantgl:281: Warning: <Shape> Field 'Geometry' has a bad value : Must be valid.
# openalea.plantgl:418: Warning: <Scene> Field 'ShapeList' has a bad '4674'th value : Must be a valid Shape.
# openalea.plantgl:86: Warning: <Oriented> Field 'Primary' has a bad value : Must be normalized.
# openalea.plantgl:281: Warning: <Shape> Field 'Geometry' has a bad value : Must be valid.
# openalea.plantgl:418: Warning: <Scene> Field 'ShapeList' has a bad '4674'th value : Must be a valid Shape.
# openalea.plantgl:86: Warning: <Oriented> Field 'Primary' has a bad value : Must be normalized.
# openalea.plantgl:281: Warning: <Shape> Field 'Geometry' has a bad value : Must be valid.
# openalea.plantgl:418: Warning: <Scene> Field 'ShapeList' has a bad '4674'th value : Must be a valid Shape.
# openalea.plantgl:86: Warning: <Oriented> Field 'Primary' has a bad value : Must be normalized.
# ...

# %% [markdown]
# Add a Soil and compute $\Psi_e$
# ===============================

# %% [markdown]
# * ### Define a heterogeneous water soil potential

# %%
soil_potential = (
[0., 0.10, 0.5, 1.],
[0.1, 0.1, 0.4, 0.8]
)
x, y = soil_potential

g = law.add_soil(g, soil_potential)

# %% [markdown]
# * ### Compute water flux on soil

# %%
g, surface, volume, Keq, Jv_global = water.hydrolic(
    g,
    segment_length=segment_length,
    ref_radius = ref_radius,
    order_decrease_factor = order_decrease_factor,
    k0 = k0,
    Jv = Jv,
    psi_e = None,
    psi_base = psi_base,
    length_data=length_data,
    axial_conductivity_data=None,
    radial_conductivity_data=radial_conductivity_data
    )

# %% [markdown]
# * ### Display water flux by taking into account soil

# %%
display_millet.plot_property(g, state = False ,prop_cmap='psi_out', lognorm= True)

# %%
#import openalea
#print openalea.__path__
# Out:
# ['c:\\python27\\lib\\site-packages\\openalea.core-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.deploy-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.deploygui-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.grapheditor-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.image-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.misc-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.numpy-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.pkgbuilder-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.pylab-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.scheduler-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.sconsx-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openalea.stdlib-1.2.0-py2.7.egg\\openalea', 'c:\\python27\\lib\\site-packages\\openal
# ...

# %% [markdown]
# * ### This code below is just for test

# %%
import openalea.plantgl as pgl
from openalea.mtg.plantframe import *
from millet import turtle
from openalea.mtg.plantframe.color import *

# %%
ages = g.property('age')
age_max = max(ages.values())
l= np.linspace(1,age_max,75)
l=map(int,l)

# %%
import openalea.plantgl.all as pgl
scenes= []
for t in l:
    g, scene = turtle.mtg_turtle_time(g,t)
    scenes.append(scene)

# %%
print len(scenes)
# Out:
# 75

# %%
scenes_len = [len(i) for i in scenes]
print scenes_len
# Out:
# [2, 152, 463, 975, 1619, 2208, 2750, 3221, 3658, 4028, 4358, 4674, 4941, 5181, 5394, 5576, 5729, 5875, 6026, 6176, 6314, 6457, 6589, 6721, 6845, 6976, 7096, 7219, 7341, 7466, 7581, 7704, 7834, 7966, 8117, 8262, 8426, 8600, 8777, 8951, 9126, 9304, 9480, 9654, 9818, 9996, 10165, 10306, 10444, 10557, 10657, 10747, 10818, 10886, 10953, 11021, 11088, 11156, 11223, 11291, 11359, 11426, 11494, 11561, 11629, 11696, 11764, 11832, 11899, 11967, 12034, 12102, 12169, 12237, 12305]

# %%
shapes = dict( (sh.getId(),sh) for sh in scenes[1])

# %%
print shapes.keys()
# Out:
# [12288, 1, 2, 12291, 12292, 12293, 12294, 12289, 12296, 12297, 12298, 12299, 12300, 12290, 12302, 12303, 12304, 12305, 18, 3, 20, 21, 22, 23, 24, 4, 26, 27, 28, 29, 30, 5, 32, 33, 34, 35, 36, 6, 38, 39, 40, 41, 42, 12295, 44, 45, 46, 47, 48, 8, 50, 51, 52, 53, 54, 9, 56, 57, 58, 59, 60, 10, 62, 63, 64, 65, 5186, 11, 5188, 5189, 5190, 5191, 5192, 12, 5194, 5195, 5196, 13, 14, 15, 16, 17, 19, 5187, 25, 68, 31, 7, 37, 69, 43, 12301, 49, 55, 61, 5003, 5004, 5005, 5006, 5007, 5008, 5009, 5010, 5011, 5012, 5013, 5014, 5015, 5016, 5017, 5018, 5019, 5020, 5021, 5022, 5023, 5024, 5025, 5026, 5027, 5028, 5029, 5030, 5031, 5032, 5193, 66, 67, 12264, 12265, 12266, 12267, 12268, 12269, 12270, 12271, 12272, 12273, 12274, 12275, 12276, 12277, 12278, 12279, 12280, 12281, 12282, 12283, 12284, 12285, 12286, 12287]

# %%
import openalea.plantgl.all as pgl
SCENES = []
for scene in scenes:
    colormap(g,'psi_out', cmap='jet', lognorm=True)
    shapes = dict( (sh.getId(),sh) for sh in scene)
    colors = g.property('color')
    for vid in shapes:
        shapes[vid].appearance = pgl.Material(colors[vid])
    scene = pgl.Scene(shapes.values())
    SCENES.append(scene)

# %%
from openalea.plantgl import *

# %%
for scene in SCENES:
    Viewer.display(scene)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-135-49a16bc02e4f> in <module>()
# ----> 1 from openalea.plantgl.all import turtle as turt
#
# ImportError: cannot import name turtle
