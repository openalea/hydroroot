# %% [markdown]
# # OpenAlea HydroRoot Gallery
# You will find below links to different Jupyter notebooks.

# %% [markdown]
# ## Measured and Simulated architectures
# These are small examples of direct water flow simulations on root simulated, RSML and measured architectures.

# %% [markdown]
# - [Read architecture from text file and run a simulation](example_archi_from_file.ipynb)
# - [Read architecture from RSML file and run a simulation](example_archi_from_rsml.ipynb)
# - [Run a simulation on a generated root](example_generated_archi.ipynb)

# %% [markdown]
# ## Parameter class
# `Parameter` is a python class that manage HydroRoot model parameters allowing for example to use yaml file as input.

# %% [markdown]
# - [Run simple calculation using the Parameters class](example_parameter_class.ipynb)

# %% [markdown]
# ## Hydraulic parameters adjustment
# These are examples showing how to determine transport parameters from experiments.

# %% [markdown]
# - [Radial conductivity](example_k_adjustment.ipynb)
# - [Solute and water transport parameters](example_solute_water_transport.ipynb)
# - [Example of cut and flow (CnF) analysis](example_cut_and_flow_analysis.ipynb)
# - [Boursiac et al. 2022](Boursiac2022/boursiac2022.ipynb)
