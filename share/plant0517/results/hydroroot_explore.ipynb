# %%
import pandas
du = pandas.read_csv('simulation_col.csv')

# %%
# %matplotlib inline
# Out:
# /Users/pradal/miniconda2/envs/adel/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
du.plot.scatter('i0', 'Jv')

# %%
du.plot.scatter('primary_length', 'Jv')

# %%
du[du.Jv>0.12]
# Out:
#        index  primary_length  axfold  radfold  length   surface        Jv  i0  \
# 10524    525            0.14     1.0      1.0  3.1743  0.001176  0.121777  50
# 21661   1662            0.16     1.0      1.0  3.1692  0.001213  0.125625  47
# 26648   6649            0.16     1.0      1.0  3.1019  0.001202  0.121447  43
# 28922   8923            0.16     1.0      1.0  3.2900  0.001250  0.128238  47
# 36175   6176            0.15     1.0      1.0  3.0892  0.001169  0.120979  49
# 37322   7323            0.15     1.0      1.0  3.1163  0.001192  0.123177  49
# 39138   9139            0.15     1.0      1.0  3.1825  0.001196  0.123970  56
# 39426   9427            0.15     1.0      1.0  3.2019  0.001187  0.124268  48
#
#            seed
# 10524  56633024
# 21661  72719959
# 26648  21374886
# 28922  74841650
# 36175  17192198
# 37322  96678099
# 39138  27260471
# 39426  76078812

# %%
cd ..
# Out:
# /Users/pradal/devlp/branches/vplants/hydroroot/share/plant0916

# %%
# %run simulation.py
# Out:
# simulation.py:38: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   pd.sort('relative_distance_to_tip', inplace=True)

# %%
select = du[du.Jv>0.12]

# %%
values = zip(select.primary_length, select.seed)

# %%
for p, s in values:
    g, axfold, radfold, _length, surface, Jv_global, i1, _seed = \
    my_run(primary_length=p, seed=s, ref_radius= 3e-4, order_decrease_factor=.75)
    print Jv_global, surface
# Out:
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.375195698831
# Global Computation Water Flux Jvg =  0.375195698831
# 0.375195698831 0.00389102252635
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.389262628755
# Global Computation Water Flux Jvg =  0.389262628755
# 0.389262628755 0.00398919336978
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.365515562128
# Global Computation Water Flux Jvg =  0.365515562128
# 0.365515562128 0.00394520910913
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.394773737269
# Global Computation Water Flux Jvg =  0.394773737269
# 0.394773737269 0.00411925530564
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.374851421304
# Global Computation Water Flux Jvg =  0.374851421304
# 0.374851421304 0.00385210997434
# entering Jv computation
# Local Computation Water Flux Jvl =
#  0.382786937601
# Global Computation Water Flux Jvg =  0.382786937601
# ...

# %%
# %gui qt

# %%
prune =0.045
#prune = 0.
scene = display.plot(g, prune=prune)
Viewer.display(scene)
